# %% [markdown]
# # 1.1 为什么用matplotlib

# %% [markdown]
# # 1.2 matplotlib 安装

# %% [markdown]
# # 2.1 基本用法

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-1,1,50) #np.linspace 定义线段取值范围
y=2*x+1
z=x**2

plt.plot(x,y)
plt.show()

plt.plot(x,z)
plt.show()

# %% [markdown]
# # 2.2 figure 图像

# %%
x1=np.linspace(-10,10,20)
y1=x1**2+3
plt.plot(x1,y1)
plt.show()

# %%
x2=np.linspace(-3,3,50)
y2=2*x+1

plt.figure()
plt.plot(x2,y2)

# %%
y3=x2**2

plt.figure(num=3,figsize=(8,5)) ##调整图像参数（调整画布参数）
plt.plot(x2,y3)

plt.show()

# %% [markdown]
# #原始未调参画布所绘图像

# %%
y3=x2**2

plt.plot(x2,y3)

plt.show()

# %%
plt.figure(num=3,figsize=(8,5)) ##调整图像参数（调整画布参数）
plt.plot(x2,y2,color='red',linewidth=10.0,linestyle='--') #调整绘图细节

plt.show()

# %%
x1=np.linspace(-2,2,30)
x2=np.linspace(-3,3,50)

y1=x1*2+6
plt.figure(num=2,figsize=(6,6))
plt.plot(x1,y1)
plt.show()

# %%
plt.figure(num=5, figsize=(7,8))
y2=x2**2
plt.plot(x2,y2)
plt.show()

# %%
plt.figure(num=3,figsize=(8,9))
plt.plot(x1,y1,color='red',linewidth=6.0, linestyle='--')
plt.plot(x2,y2,color='blue',linewidth=3.0,linestyle="-")
plt.show()

# %% [markdown]
# # 2.3 设置坐标轴1

# %% [markdown]
# 修改坐标轴标签

# %%
plt.figure(num=3,figsize=(6,6))
plt.plot(x2,y2)
plt.plot(x1,y1, color='red',linewidth=1.0, linestyle='--')
plt.xlim((-10,10))
plt.ylim((-10,10))
plt.xlabel('I an x')
plt.ylabel('I am y')
plt.show()

# %%
plt.figure(num=3,figsize=(6,6))
plt.plot(x2,y2)
plt.plot(x1,y1, color='red',linewidth=1.0, linestyle='--')
plt.xlim((-10,10))
plt.ylim((-10,10))
plt.xlabel('I an x')
plt.ylabel('I am y')

new_ticks = np.linspace(-10,10,5)
print(new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2,0,2,4,6,],
          [r'$really bad //alpha$',r'$bad//alpha$',r'$normal//alpha$',r'$good//alpha$',r'$really good//alpha$'])
plt.show()
# Out:
# [-10.  -5.   0.   5.  10.]

# %% [markdown]
# # 2.4设置坐标轴2

# %% [markdown]
# 修改坐标轴的位置

# %%
plt.figure(num=3,figsize=(6,6))
plt.plot(x2,y2)
plt.plot(x1,y1, color='red',linewidth=1.0, linestyle='--')
plt.xlim((-10,10))
plt.ylim((-10,10))
plt.xlabel('I an x')
plt.ylabel('I am y')

new_ticks = np.linspace(-10,10,5)
print(new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2,0,2,4,6,],
          [r'$really\ bad\ \alpha$',r'$bad\ \alpha$',r'$normal\ \alpha$',r'$good\ \alpha$',r'$really\ good\  \alpha$'])

#gca = 'get current axis'
#设置坐标轴
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))#outward,axes
ax.spines['left'].set_position(('data',0))

plt.show()
# Out:
# [-10.  -5.   0.   5.  10.]

# %% [markdown]
# # 2.5 Legend 图例

# %%
plt.figure(num=3,figsize=(6,6))
#plt.plot(x2,y2)
#plt.plot(x1,y1, color='red',linewidth=1.0, linestyle='--')
plt.xlim((-10,10))
plt.ylim((-10,10))
plt.xlabel('I an x')
plt.ylabel('I am y')

new_ticks = np.linspace(-10,10,5)
print(new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2,0,2,4,6,],
          [r'$really\ bad\ \alpha$',r'$bad\ \alpha$',r'$normal\ \alpha$',r'$good\ \alpha$',r'$really\ good\  \alpha$']) ##$$原始字符串

#gca = 'get current axis'
#设置坐标轴
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))#outward,axes
ax.spines['left'].set_position(('data',0))

#设置图例
l1=plt.plot(x2,y2,label='up')
l2=plt.plot(x1,y1, color='red',linewidth=1.0, linestyle='--',label='down')
plt.legend(handles=[l1,l2],labels=['aaa','bbb'],loc='best') #'upper right','upper left','lower right','lower left'

plt.show()
# Out:
# [-10.  -5.   0.   5.  10.]
# <ipython-input-46-100f34847046>:28: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x00000178144E8820>] instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(handles=[l1,l2],labels=['aaa','bbb'],loc='best') #'upper right','upper left','lower right','lower left'
# <ipython-input-46-100f34847046>:28: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x00000178142ECE80>] instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(handles=[l1,l2],labels=['aaa','bbb'],loc='best') #'upper right','upper left','lower right','lower left'

# %% [markdown]
# # 2.6 Annotation 注解

# %%
x=np.linspace(-3,3,10)
y=x*2+3
plt.figure(num=3,figsize=(4,5))
plt.plot(x,y)

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))#outward,axes
ax.spines['left'].set_position(('data',0))

x0=1
y0=2*x0+3
plt.scatter(x0,y0,s=50,color='b') ##'b'=blue
plt.plot([x0,x0],[y0,0],'k--',lw=2.5)

#method 1
plt.annotate(r'$2x+1=%s$'%y0,xy=(x0,y0),xycoords='data',xytext=(+30,-30),textcoords='offset points',fontsize=16,
             arrowprops=dict(arrowstyle='->',connectionstyle='arc3,rad=.2'))

#method 2
plt.text(-3.7,3,r'$This\ is\ the\ text.\ \mu\ \sigma_i\ \alpha_t$',fontdict={'size':16,'color':'r'})

plt.show()

# %% [markdown]
# # 2.7 tick能见度 axis tick 坐标轴刻度

# %%
x=np.linspace(-3,3,50)
y=0.1*x
#plt.figure(num=3,figsize=(4,5))
plt.figure()
plt.plot(x,y,linewidth=10)
plt.ylim(-2,2)

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))#outward,axes
ax.spines['left'].set_position(('data',0))

for label in ax.get_xticklabels()+ax.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='white',edgecolor='None',alpha=0.5)) ## alpha 不透明度

plt.show()

# %% [markdown]
# # 3.1 Scatter 散点图

# %%
import matplotlib.pyplot as plt
import numpy as np
#import pandas as pd

# %%
n=1024
X=np.random.normal(0,1,n)
Y=np.random.normal(0,1,n)
T=np.arctan2(Y,X) #for color value

plt.scatter(X,Y,s=75,c=T,alpha=0.5)

plt.xlim((-1.5,1.5))
plt.ylim((-1.5,1.5))
plt.xticks(())#隐藏所有x轴ticks
plt.yticks(())
plt.show()

# %%
n=1024
X=np.random.normal(0,1,n)
Y=np.random.normal(0,1,n)
T=np.arctan2(Y,X) #for color value

##plt.scatter(X,Y,s=75,c=T,alpha=0.5)
plt.scatter(np.arange(5),np.arange(5))
#plt.xlim((-1.5,1.5))
#plt.ylim((-1.5,1.5))
plt.xticks(())#隐藏所有ticks
plt.yticks(())
plt.show()

# %% [markdown]
# # 3.2 Bar 柱状图

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n=12
X=np.arange(n)
Y1=(1-X/float(n))*np.random.uniform(0.5,1.0,n)
Y2=(1-X/float(n))*np.random.uniform(0.5,1.0,n)

plt.bar(X,+Y1,facecolor='#9999ff',edgecolor='white')
plt.bar(X,-Y2,facecolor='#ff9999',edgecolor='white')

for x,y in zip(X,Y1): #将X,Y1分别传入x,y
##ha:horizontal alignment
#va: vertical alignment
   plt.text(x+0.4,y+0.05,'%.2f'%y,ha='center',va='bottom')

for x,y in zip(X,Y2): #将X,Y1分别传入x,y

   plt.text(x+0.4,-y-0.05,'-%.2f'%y,ha='center',va='top') 
    
plt.xlim(-.5,n)
plt.xticks(())
plt.ylim(-1.25,1.25)
plt.yticks(())

plt.show()

# %% [markdown]
# # 3.3 Contours 等高线图

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x,y):
    #the height function
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n=256
x=np.linspace(-3,3,n)
y=np.linspace(-3,3,n)
X,Y=np.meshgrid(x,y)
#use plt.contourf to filling contours
#X,Y and value for (X,Y) point
plt.contourf(X,Y,f(X,Y),10,alpha=0.75,cmap=plt.cm.hot)  #"hot" or "cool"

#use plt.contour to add contour lines 
C=plt.contour(X,Y,f(X,Y),10,colors='black',linewidth=.5) 

#adding label
plt.clabel(C,inline=True,fontsize=10) #"True"：数值在线里面 "False":数值直接穿过图线

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# <ipython-input-96-5eb295cc951c>:14: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   C=plt.contour(X,Y,f(X,Y),10,colors='black',linewidth=.5)

# %%
def f(x,y):
    #the height function
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n=256
x=np.linspace(-3,3,n)
y=np.linspace(-3,3,n)
X,Y=np.meshgrid(x,y)
#use plt.contourf to filling contours
#X,Y and value for (X,Y) point
plt.contourf(X,Y,f(X,Y),100,alpha=0.75,cmap=plt.cm.cool)  #"hot" or "cool"

#use plt.contour to add contour lines 
C=plt.contour(X,Y,f(X,Y),100,colors='black',linewidth=.5) 
#adding label

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# <ipython-input-89-189726412b93>:14: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   C=plt.contour(X,Y,f(X,Y),100,colors='black',linewidth=.5)

# %% [markdown]
# # 3.4 Image 图片

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#image data
data=np.random.rand(3,3)
data
data1=np.sort(data)
print(data1)
# Out:
# [[0.29983721 0.52249819 0.84775617]
#  [0.48647558 0.58494258 0.77192551]
#  [0.48078699 0.7569617  0.99986415]]

# %%
a = np.random.rand(3, 3)
print(a)
# Out:
# [[0.83780551 0.11990349]
#  [0.91832032 0.92306671]
#  [0.79420486 0.59389656]]

# %%
a = np.random.uniform(0, 1, (3, 3))
print(a)
# Out:
# [[0.64292641 0.27523756 0.45099413]
#  [0.85537252 0.64717432 0.77491312]
#  [0.18873087 0.92698686 0.12371652]]

# %%
b =np.sort(a)
print(b)
# Out:
# [[0.27523756 0.45099413 0.64292641]
#  [0.64717432 0.77491312 0.85537252]
#  [0.12371652 0.18873087 0.92698686]]

# %%
c=np.array(a).reshape(1,9)
print(c)
# Out:
# [[0.64292641 0.27523756 0.45099413 0.85537252 0.64717432 0.77491312
#   0.18873087 0.92698686 0.12371652]]

# %%
d=np.sort(c)
print(d)
# Out:
# [[0.12371652 0.18873087 0.27523756 0.45099413 0.64292641 0.64717432
#   0.77491312 0.85537252 0.92698686]]

# %%
e=np.array(d).reshape(3,3)
print(e)
# Out:
# [[0.12371652 0.18873087 0.27523756]
#  [0.45099413 0.64292641 0.64717432]
#  [0.77491312 0.85537252 0.92698686]]

# %%
plt.imshow(b,interpolation='nearest',cmap='bone',origin='upper')  
plt.xticks(())
plt.yticks(())
plt.show()

# %%
## ##interpolation : https://matplotlib.org/3.2.1/gallery/images_contours_and_fields/interpolation_methods.html

##interpolation :  methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
##               'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
##               'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

# %%
plt.imshow(e,interpolation='nearest',cmap='bone',origin='upper')  

plt.xticks(())
plt.yticks(())
plt.show()

# %%
plt.imshow(e,interpolation='nearest',cmap='bone',origin='lower')  
plt.xticks(())
plt.yticks(())
plt.show()

# %%
plt.imshow(e,interpolation='gaussian',cmap='bone',origin='lower')  
plt.xticks(())
plt.yticks(())
plt.show()

# %%
plt.imshow(e,interpolation='gaussian',cmap='bone',origin='lower')  
##plt.xticks(())
##plt.yticks(())
plt.colorbar(shrink=0.9)
plt.show()

# %% [markdown]
# # 3.4 3D plot 3D数据

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax= Axes3D(fig)

#X,Y value
X=np.arange(-4,4,0.25)
Y=np.arange(-4,4,0.25)
X,Y=np.meshgrid(X,Y)
R=np.sqrt(X**2+Y**2)

#height value
Z=np.sin(R)

ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=plt.get_cmap('rainbow'))
ax.contourf(X,Y,Z,zdir='z',offset=-2,cmap='rainbow')  #放置等高线轴
ax.set_zlim(-2,2)
plt.show()

# %% [markdown]
# # 4.1 Subplot 多合一显示

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot([0,1],[0,1])

plt.subplot(2,2,2)
plt.plot([0,1],[0,2])

plt.subplot(2,2,3)
plt.plot([0,1],[0,3])

plt.subplot(2,2,4)
plt.plot([0,1],[0,4])

plt.show()

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot([0,1],[0,1])

plt.subplot(2,3,4)
plt.plot([0,1],[0,2])

plt.subplot(235)
plt.plot([0,1],[0,3])

plt.subplot(236)
plt.plot([0,1],[0,4])

plt.show()

#每个图表的位置按照网格来算，最小单位方格数量作为记位数

# %% [markdown]
# # 4.2 Subplot in grid 分格显示

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
##method 1 :subplot2grid

plt.figure()
ax1=plt.subplot2grid((3,3),(0,0),colspan=3,rowspan=1)
ax1.plot([1,2],[1,2])
ax1.set_title('ax1_title')

ax2=plt.subplot2grid((3,3),(1,0),colspan=2) #默认 rowspan=1
ax3=plt.subplot2grid((3,3),(1,2),rowspan=2)
ax4=plt.subplot2grid((3,3),(2,0))
ax5=plt.subplot2grid((3,3),(2,1))

plt.show()

# %%
##method 2 :gridspec
import matplotlib.gridspec as gridspec
plt.figure()
gs=gridspec.GridSpec(3,3)
ax1=plt.subplot(gs[0,])  #用索引的方式确定行列
ax2=plt.subplot(gs[1,:2])
ax3=plt.subplot(gs[1:,2])
ax4=plt.subplot(gs[-1,0])
ax5=plt.subplot(gs[-1,-2])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\gridspec.py in __getitem__(self, key)
#     232             try:
# --> 233                 k1, k2 = key
#     234             except ValueError as err:
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-06577ffc3c82> in <module>
#       3 plt.figure()
#       4 gs=gridspec.GridSpec(3,3)
# ----> 5 ax1=plt.subplot(gs[0,])  #用索引的方式确定行列
#       6 ax2=plt.subplot(gs[1,:2])
#       7 ax3=plt.subplot(gs[1:,2])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\gridspec.py in __getitem__(self, key)
#     233                 k1, k2 = key
#     234             except ValueError as err:
# ...

# %%
##method 3 :easy to define structure

f,((ax11,ax12),(ax21,ax22)) = plt.subplots(2,2,sharex=True,sharey=True)
ax11.scatter([1,2],[1,2])

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.3 plot in plot 图中图

# %%
import matplotlib.pyplot as plt

# %%
fig= plt.figure()
x=[1,2,3,4,5,6,7]
y=[1,3,4,2,5,8,6]

left,bottom,width,height=0.1,0.1,0.8,0.8
ax1=fig.add_axes([left,bottom,width,height])
ax1.plot(x,y,'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')

left,bottom,width,height=0.2,0.6,0.25,0.25
ax1=fig.add_axes([left,bottom,width,height])
ax1.plot(y,x,'b')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title inside 1')

plt.axes([.6,0.2,0.25,0.25])
plt.plot(y[::-1],x,'g')
plt.xlabel('x')
plt.ylabel('y') 
plt.title('title inside 2')
# Out:
# Text(0.5, 1.0, 'title inside 2')

# %% [markdown]
# # 4.4 secondary axis次坐标轴 双坐标轴

# %% [markdown]
# twinx: 共享x轴 镜面反射 ？ twiny:共享y轴

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(0,10,0.1)
y1=0.05*x**2
y2=-1*y1

fig, ax1=plt.subplots()
ax2=ax1.twinx()
ax1.plot(x,y1,'g-')
ax2.plot(x,y2,'b--')

ax1.set_xlabel('X data')
ax1.set_ylabel('Y1',color='g')
ax2.set_ylabel('Y2',color='b')

plt.show()

# %% [markdown]
# # 4.5 Animation 动画

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# %%
x=np.arange(0,2*np.pi,0.01)
line,=ax.plot(x,np.sin(x))

def animate(i):
    line.set_ydata(np.sin(x+i/10))
    return line,

def init():
    line.set_ydata(np.sin(x))
    return line,
    
ani = animation.FuncAnimation(fig=fig, func=animate, frames=100, init_func=init, interval=20,blit=False)
plt.show()
